# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('/Users/wujiayou/Desktop/projects/Food Nutritional Facts/foodstruct_nutritional_facts.csv')

# %%
df.head(3)
# Out:
#   Food Name Category Name  Calcium  Calories  Carbs  Cholesterol   Copper  \
# 0   Acerola        Fruits    0.012      32.0    7.7          0.0  0.00009
# 1     Apple        Fruits    0.006      52.0   14.0          0.0  0.00003
# 2   Apricot        Fruits    0.013      48.0   11.0          0.0  0.00008
#
#    Fats  Fiber    Folate  ...  Vitamin D  Vitamin E  Vitamin K  Omega-3 - ALA  \
# 0  0.30    1.1  0.000014  ...        NaN        NaN        NaN            NaN
# 1  0.17    2.4  0.000003  ...        0.0    0.00018   0.000002            NaN
# 2  0.39    2.0  0.000009  ...        0.0    0.00089   0.000003            NaN
#
#    Omega-6 - Eicosadienoic acid  Omega-6 - Gamma-linoleic acid  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
#
#    Omega-3 - Eicosatrienoic acid  Omega-6 - Dihomo-gamma-linoleic acid  \
# ...

# %%
corr=df.select_dtypes([int,float]).corr()

plt.figure(figsize=(20,20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size': 6},cmap='coolwarm')

# %%
df.groupby('Category Name')['Vitamin D'].mean().sort_values(ascending=False).plot.bar()

# %%
df.groupby('Category Name')['Protein'].mean().sort_values(ascending=False).plot.bar()

# %%
fruits = df[df['Category Name']=='Fruits']

# %%
fruits['Calories'].sort_values(ascending=False)
# Out:
# 82    354.0
# 22    349.0
# 61    299.0
# 17    282.0
# 3     241.0
#       ...
# 32     29.0
# 41     28.0
# 80     25.0
# 65     25.0
# 85     21.0
# Name: Calories, Length: 89, dtype: float64

# %%
fruits.sort_values(by='Calories', ascending=False)
# Out:
#        Food Name Category Name  Calcium  Calories  Carbs  Cholesterol  \
# 82       Coconut        Fruits    0.014     354.0   15.0          0.0
# 22  Goji berries        Fruits    0.190     349.0   77.0          0.0
# 61        Raisin        Fruits    0.050     299.0   79.0          0.0
# 17         Dates        Fruits    0.039     282.0   75.0          0.0
# 3    Dried fruit        Fruits    0.055     241.0   63.0          0.0
# ..           ...           ...      ...       ...    ...          ...
# 32         Lemon        Fruits    0.026      29.0    9.3          0.0
# 41         Melon        Fruits    0.011      28.0    6.6          0.0
# 80    Naranjilla        Fruits    0.008      25.0    5.9          NaN
# 65    Rose apple        Fruits    0.029      25.0    5.7          0.0
# 85  Banana melon        Fruits    0.013      21.0    4.1          NaN
#
#      Copper   Fats  Fiber    Folate  ...  Vitamin D  Vitamin E     Vitamin K  \
# ...
